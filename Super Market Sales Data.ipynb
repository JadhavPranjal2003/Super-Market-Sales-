# %% [markdown]
#  # **Super Market Sales Data**

# %% [markdown]
# Grocery Stores are a vital part of everyday life, providing us with the food and essentials as we need. Many people utilize grocery delivery applications to order their products, making it easy to shop from home. Each transaction made through these applications is recorded in detail, creating a valuable dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Importing Laibraries

# %%
df=pd.read_csv("/content/drive/MyDrive/Python Project/supermarket_sales_dataset.csv")
df
# Out:
#      Transation_ID        Date Customer ID  Gender     City Product Category  \
# 0                1  24-11-2023     CUST001    Male     Pune           Beauty
# 1                2  27-02-2023     CUST002  Female     Pune         Clothing
# 2                3  13-01-2023     CUST003    Male  Kolkata      Electronics
# 3                4  21-05-2023     CUST004    Male     Pune         Clothing
# 4                5  06-05-2023     CUST005    Male     Pune           Beauty
# ..             ...         ...         ...     ...      ...              ...
# 995            996  16-05-2023     CUST996    Male   Nashik         Clothing
# 996            997  17-11-2023     CUST997    Male   Nashik           Beauty
# 997            998  29-10-2023     CUST998  Female     Pune           Beauty
# 998            999  05-12-2023     CUST999  Female   Mumbai      Electronics
# 999           1000  12-04-2023    CUST1000    Male   Nashik      Electronics
#
# ...

# %% [markdown]
# Read the Supermarket_Sales Data file

# %% [markdown]
# # **Data Cleanning**

# %%
df.head()
# Out:
#    Transation_ID        Date Customer ID  Gender     City Product Category  \
# 0              1  24-11-2023     CUST001    Male     Pune           Beauty
# 1              2  27-02-2023     CUST002  Female     Pune         Clothing
# 2              3  13-01-2023     CUST003    Male  Kolkata      Electronics
# 3              4  21-05-2023     CUST004    Male     Pune         Clothing
# 4              5  06-05-2023     CUST005    Male     Pune           Beauty
#
#    Age      Payment  Quantity  Price per Unit  Total Amount
# 0   53      Ewallet         3              50           150
# 1   34         Cash         2             500          1000
# 2   26  Credit card         1              30            30
# 3   50      Ewallet         1             500           500
# 4   37      Ewallet         2              50           100

# %% [markdown]
# df.head() function is used to read the top 5 rows in the table.indexing is always starts with 0 so that it stop with 4.

# %%
df.tail()
# Out:
#      Transation_ID        Date Customer ID  Gender    City Product Category  \
# 995            996  16-05-2023     CUST996    Male  Nashik         Clothing
# 996            997  17-11-2023     CUST997    Male  Nashik           Beauty
# 997            998  29-10-2023     CUST998  Female    Pune           Beauty
# 998            999  05-12-2023     CUST999  Female  Mumbai      Electronics
# 999           1000  12-04-2023    CUST1000    Male  Nashik      Electronics
#
#      Age      Payment  Quantity  Price per Unit  Total Amount
# 995   41      Ewallet         1              50            50
# 996   62      Ewallet         3              30            90
# 997   52      Ewallet         4              25           100
# 998   23  Credit card         3              50           150
# 999   36  Credit card         4              30           120

# %% [markdown]
# df.tail() it is used to read last 5 rows.by default give the indexing.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transation_ID     1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   City              1000 non-null   object
#  5   Product Category  1000 non-null   object
#  6   Age               1000 non-null   int64
#  7   Payment           1000 non-null   object
#  8   Quantity          1000 non-null   int64
#  9   Price per Unit    1000 non-null   int64
#  10  Total Amount      1000 non-null   int64
# dtypes: int64(5), object(6)
# memory usage: 86.1+ KB

# %% [markdown]
# Give the Information about the table. how many rows, how many coloumns, name of that columns, null values, not null value, datatype of that column, also give the memory use age that data.

# %%
df.shape
# Out:
# (1000, 11)

# %% [markdown]
# Give the number of Rows and Columns in the Table

# %%
df.describe().T
# Out:
#                  count     mean         std   min     25%    50%     75%  \
# Transation_ID   1000.0  500.500  288.819436   1.0  250.75  500.5  750.25
# Age             1000.0   41.398   13.685207  18.0   29.00   42.0   53.00
# Quantity        1000.0    2.514    1.132734   1.0    1.00    3.0    4.00
# Price per Unit  1000.0  179.890  189.681356  25.0   30.00   50.0  300.00
# Total Amount    1000.0  456.000  559.997632  25.0   60.00  135.0  900.00
#
#                    max
# Transation_ID   1000.0
# Age               64.0
# Quantity           4.0
# Price per Unit   500.0
# Total Amount    2000.0

# %% [markdown]
# It is used for Describing the all aggregate function in the Table like mean, max, min, count, std, etc.

# %%
df.isnull().sum()
# Out:
# Transation_ID       0
# Date                0
# Customer ID         0
# Gender              0
# City                0
# Product Category    0
# Age                 0
# Payment             0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %% [markdown]
# isnull() is used for checking value is null or not, give the output in boolean and if we check count of null values then use sum() function, it gives only count of number.

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# 1.Which product category is more profitable?

# %%
sns.barplot(data=df,x="Product Category",y="Total Amount",hue="Product Category")
plt.xticks(rotation=30);

# %% [markdown]
# There are not much difference between profit but, Furniture are more profitable than others. beacause furniture is more solded product.the secound one is beauty and electronics are sale same.then footware & shoes, clothing,   stationnery and then last one is food.

# %% [markdown]
# 2.Who male or female purchase more products?

# %%
sns.countplot(data=df,x='Gender',hue='Gender');

# %% [markdown]
# Here not much difference but, Females are sold more Products than males.This marginal difference in quantity indicates that female customers are more active shoppers.Certain product categories such as clothing, beauty, and electrionics  have stronger knowledge to female customers.

# %% [markdown]
# 3.Showing citywise total amount using colorbar?

# %%
plt.scatter(data=df,x='City',y='Total Amount')
plt.xlabel('City')
plt.ylabel('Total Amount')
plt.xticks(rotation=30)
plt.colorbar();

# %% [markdown]
# With the help of Scatter and Colorbar showing the Citywise Total Amount.here Pune ,Nashik and Mumbai City are Sold more Products. As per colorbar, bold color is show more sales and less bold color shows the less sales. attach dot shows more sale and space is show not sale is done.

# %% [markdown]
# 4.In Which City sold more Products?

# %%
sns.histplot(data=df,x='City',hue='City')
plt.xticks(rotation=20);

# %% [markdown]
# Pune is a city which sold the highest Products than Nashik and Mumbai. In that 3 city sold much products. but other city's not sales more products.others are kolkata, surat, satara, bangalor that city not sales more products.

# %% [markdown]
# 5.What are the percentage of sold product by City in each product Category?

# %%
sizes = [20,5,15,4,19,8,5]
labels = ['Pune','Kolkata','Mumbai','Bangalor','Nashik','Surat','Satara']
plt.pie(sizes, labels=labels, autopct='%1.1f%%');

# %% [markdown]
# Here we can represent the percentage wise cities. here also pune is more profitable, it sold 26.3% products. nashik sold 25.0%, mumbai sold 19.7%, surat sold 10.5%, kolkata and satara sold same that is 6.6% and bangalor sold 5.3% products. so all that city pune is profitable city for sold products.

# %% [markdown]
# 6.Which Category of male and female spend a lot of Payment option based on age ?

# %%
sns.stripplot(data=df,x='Payment',y='Age',hue='Gender');

# %% [markdown]
# Age of above 50 Females are used more Ewallet and males are use more Cash.Younger customers i.e 18-25 age group may spend more using modern payment methods like mobile payments or credit cards.Middle-aged customers i.e 30-50 age group might prefer credit cards or bank transfers for larger purchases Senior customers  might prefer cash due to familiarity and ease of use.

# %% [markdown]
# 7.Which is the most pouplar payment method used by customers?

# %%
sns.countplot(data=df,x='Payment',hue='Payment');

# %% [markdown]
# The most popular payment method is E-wallet. Cash payment is also popular. but credit card are not much popular.for purpose of safty all of use E-wallet, then the person don't use online payments and credit card users is very less than others.

# %% [markdown]
# 8.Which Product category of male and female spend a lot based on age ?

# %%
sns.catplot(data=df,y='Age', x='Product Category',hue='Gender',kind='bar')
plt.xticks(rotation=40);

# %% [markdown]
# Males of 40-50 age group are spend on food,Beauty and footwear and shoes.females of 40-50 age group are spend almost all products like Beauty, clothing, electronics, stationery, furniture and food. 30-40 age group females are use footware and shoes and 30-40 age group males are used clothing, electronics, stationary and furniture.

# %% [markdown]
# 9.What is the Total Amount for each payment method?

# %%
sns.boxplot(data=df,x='Payment',y='Total Amount',hue='Gender');

# %% [markdown]
# Here Total Amount of Ewallet is between 750-1000, cash is between 500-750,credit card is also between 500-750. In E-wallet,male and female spend same amount. In cash payment male and female also spend same amount. but in credit card male are spend more amount than females.

# %% [markdown]
# 10.Find Quantity wise how many product are sold?

# %%
sns.lineplot(data = df, y = 'Quantity' , x= 'Product Category',hue='Gender',ci=False);
plt.xticks(rotation=20);
# Out:
# <ipython-input-18-b7e823ec76d7>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(data = df, y = 'Quantity' , x= 'Product Category',hue='Gender',ci=False);

# %% [markdown]
# According to the total amount furniture is more profitable but in the quantity purchase is low. In male highest quantity in stationary, and more than 2.4 quantity in beauty, clothing, electronics, footwear and shoes. The lowest quantity in furniture and food. In the female highest quantity in electronics ,more than 2.4 quantity in beauty and clothing. less than 1.8 to 2.4 quantity in footware and shoes,furniture and food. lowest quantity in stationery.

# %% [markdown]
# 11.What is the correlation between quantity purchased and total amount spent by male and female?

# %%
sns.lmplot(data = df, x = 'Quantity' , y= 'Total Amount',ci=False,hue='Gender',col='Gender');

# %% [markdown]
# Here Positive Correlation between total amount and quantity. Both correlations are positive, indicating that as the quantity purchased increases, the total amount spent also tends to increase for both genders, with a higher correlation for female customers.

# %% [markdown]
# 12.Which Product Category is sold more using plotly bar ?

# %%
fig = px.bar(df, x='Product Category', y='Total Amount', color='Gender')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# According to plotly bar, Electronics and clothing are sold more, but females are sold more clothing and male are sold more electronics. secound one is beauty, In that females are sold more beauty products as compare to males, In stationary male sold more stationary than females, In footware and shoes also male sold more than females, In furniture female are sale more furniture than males, In food male are sold more foods as compare to females.

# %% [markdown]
# 13. Plot the Sum of Total Sales of each City

# %%
ax = sns.barplot(x='City', y = 'Total Amount', hue = 'City', data = df, estimator=sum)
plt.xlabel('City')
plt.ylabel('Sum of Sales');

# %% [markdown]
# Each bar will represent a city, and the height of the bar will correspond to the total sales for that city.Sum of sale is Highest in Pune City.the total sum is between 150000 to 175000.secound one is nashik  it is also grater than 150000. mumbai's total sum is 100000. that 3 city is above 100000 but other is below of 25000 i.e kolkata,bangalor,surat,satara.

# %% [markdown]
# 14.Count the order Quantity of City?

# %%
sns.countplot(x=df['City'],order=df['City'].value_counts().index[0:5])
plt.ylabel('Quantity')
plt.xlabel('City');

# %% [markdown]
# Each bar will represent the Quantity of product sales in each city. Highest Quantity in Pune City.highest quantity is above 350. Second highest is between 300-350 in nashik city. mumbai is 250 and other are below 50.

# %% [markdown]
# 15.    Find Quantity of Price per Unit?

# %%
sns.violinplot(x='Quantity',y='Price per Unit',data=df);

# %% [markdown]
# Here we can see, 1 and 4 Quantity is most of used. then 2 quantity is used and 3 quantity is less than others.

# %% [markdown]
# 16.Find the count of Total Amount?

# %%
his = px.histogram(df, x="Total Amount")
his.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Count of Total Amount is higher in between 0-90 because of the product price is not costly and Sutiable to all, then between 100-190 the count is 193.the amount between 200-290 the count is 62. In 300-390 the count is 46. between 390-500 no any count of total amount. between 500-590 amount count is 51 and between 600-690 total amount count is 35. then directly total amount is start from 900-990 and count is 62 and other are as in graf.

# %% [markdown]
# 17.What are the Percentage of type of payment is more than done ?

# %%
fig = px.pie(df, names = 'Payment')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Here we can see Ewallet payment option is most of used. for Ewallet there is 40.6 % payment option is used. for cash there is 34.1 % is used and credit card is used 25.3 %.

# %% [markdown]
# 18.Find Product Category as per price per unit?

# %%
fig = px.box(df, x = 'Product Category',y = 'Price per Unit',color = 'Product Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# According to Price per unit, footwear and shoes and furniture are highest product sold. also all products are positive skewed but only furniture in negative skewed. footwear and shoes are above 300 and others are 300 or below 300.

# %% [markdown]
# 19.show the Highest Quantity of Product ?

# %%
fig = px.scatter(df, x = 'Quantity', y = 'Total Amount',color = 'Product Category',size = 'Total Amount',hover_name = 'Product Category')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The Highest Quentity is 4 and highest product is furniture. then secound one is food and quantity is also 4.

# %% [markdown]
# 20.Show the multivariate analysis using a correlation matrix plot?

# %%
sns.heatmap(data=df[['Price per Unit','Total Amount','Quantity']].corr(), annot=True, cbar=True);

# %% [markdown]
# Here we can see, 0.2 to 0.4 is represent strong correlation while 0.6 to 1.0 is repesent week correlation. 1,0.85 and 0.37 is a positive corrlation beacuse of it moves the same direction and 0.018 is represent the negative corelation.

# %% [markdown]
# 21.Find the Count of Quantity?

# %%
sns.countplot(data=df,x='Quantity',hue='Gender');

# %% [markdown]
# Here we can see, highest Quantity is 4 which is sold by female and In male highest Quantity is 1. females lowest quantity is 2 and males lowest quantity is 3. as compare to male and female, males higher quantity is 1 and 2. females higher quantity is 3 and 4.

# %% [markdown]
# 22. Find Date wise sum of Total Amount?

# %%
plt.plot(df.groupby('Date')['Total Amount'].sum().head(10),linestyle='--',marker='o')
plt.xticks(rotation=90);

# %% [markdown]
# Date of 01-02-2023 sale more products. The highest score is above 4000. 01-04-2023 is also above 4000. 01-01-2023 is above 3000 and between 3000-4000. others are below of 2000.

# %% [markdown]
# 23.Which Payment option is most of used in age  using lineplot

# %%
sns.lineplot(data=df,x='Payment',y='Age',hue='Gender',ci=True);
# Out:
# <ipython-input-18-dcb40ea31100>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', True)` for the same effect.
#
#   sns.lineplot(data=df,x='Payment',y='Age',hue='Gender',ci=True);

# %% [markdown]
# Ewallet option is most of used in age group of 42.0-42.5. then between 40.5-41.5 used cash as well as credit cards. most of females are more used Ewallet than males. males are most used credit cards.

# %% [markdown]
#  ** # Conclusion :

# %% [markdown]
# In this analysis, we've looked at important aspects of the supermarket’s sales, revealing insights that can guide future decisions. Branch C leads in sales, and the popularity of electronic accessories and the sales in different cities provide valuable insights. Plus, the positive customer ratings suggest the supermarket offers a good shopping experience.
